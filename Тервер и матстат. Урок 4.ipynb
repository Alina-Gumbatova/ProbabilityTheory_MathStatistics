# %% [markdown]
# # Практическое задание 4

# %% [markdown]
# ## по теме: "Непрерывные случайные величины. Функция распределения и плотность распределения вероятностей. Равномерное и нормальное распределение. Центральная предельная теорема"

# %% [markdown]
# **Задача 1.**
#
# Случайная непрерывная величина A имеет равномерное распределение на промежутке (200, 800].
# Найдите ее среднее значение и дисперсию.

# %% [markdown]
# Математическое ожидание $M(X)$ равномерно распределенной непрерывной случайной величины можно вычислить по формуле:

# %% [markdown]
# $$M(X) = \frac{a + b}{2}$$

# %% [markdown]
# $$M(X) = \frac{200 + 800}{2} = 500$$

# %% [markdown]
# По следующей формуле можно рассчитать дисперсию $D(X)$:

# %% [markdown]
# $$D(X) = \frac{(b - a)^2}{12}$$

# %% [markdown]
# $$D(X) = \frac{(b - a)^2}{12} = 30000$$

# %% [markdown]
# **Задача 2.**
#
# О случайной непрерывной равномерно распределенной величине B известно, что ее дисперсия равна 0.2.
# Можно ли найти правую границу величины B и ее среднее значение зная, что левая граница равна 0.5?
# Если да, найдите ее.

# %% [markdown]
# Из формулы для дисперсии следует, что

# %% [markdown]
# $$b = {(12D)^{0.5} + a} = 2,05$$

# %% [markdown]
# **Задача 3.**
#
# Непрерывная случайная величина X распределена нормально и задана плотностью распределения
# f(x) = (1 / (4 * sqrt(2*pi))) * (exp(-((x+2)^2) / 32))
#
# Найдите:
#
# а). M(X)
#
# б). D(X)
#
# в). std(X) (среднее квадратичное отклонение)

# %% [markdown]
# $$f(x) = \frac{1}{\sigma \sqrt{2 \pi}} e ^ {- \frac{(x - a)^2}{2 \sigma^2}}$$

# %% [markdown]
# где $a = M(X), \; \sigma^2 = D(X).$

# %% [markdown]
# Следовательно,
#
# где $M(X) = -2, \; \sigma = 4, \; D(X) = 16.$

# %% [markdown]
# **Задача 4.**
#
# Рост взрослого населения города X имеет нормальное распределение.
# Причем, средний рост равен 174 см, а среднее квадратичное отклонение равно 8 см.
# Какова вероятность того, что случайным образом выбранный взрослый человек имеет рост:
#
# а). больше 182 см
#
# б). больше 190 см
#
# в). от 166 см до 190 см
#
# г). от 166 см до 182 см
#
# д). от 158 см до 190 см
#
# е). не выше 150 см или не ниже 190 см
#
# ё). не выше 150 см или не ниже 198 см
#
# ж). ниже 166 см.

# %% [markdown]
# На отрезке от $-\sigma$ до $+\sigma$ расположено около 68 % наблюдений,
#
# от $-2\sigma$ до $+2\sigma$ — 95.4 %,
#
# и от $-3\sigma$ до $+3\sigma$ — 99.72 %.

# %% [markdown]
# а). 1 - 0,5 - 0,34 = 0,16
#
# б). (1 - 0,9972) / 2 = 0,0014
#
# в). 0,68 + 0,137 = 0,817
#
# г). 0,68
#
# д). 0,954
#
# е). 0,0014 + 0,023 = 0,0244
#
# ё). 0,0028
#
# ж). 1 - 0,5 - 0,34 = 0,16

# %% [markdown]
# **Задача 5.**
#
# На сколько сигм (средних квадратичных отклонений) отклоняется рост человека, равный 190 см, от
# математического ожидания роста в популяции, в которой M(X) = 178 см и D(X) = 25 кв.см?

# %% [markdown]
# Ср. квадратич. отклонение = 5
#
# (190 - 178) / 5 = 2,4
